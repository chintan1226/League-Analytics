# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data_table = pd.read_csv("lec_playerdata.csv")

dataset = np.array(data_table)

data_table
# Out:
#         Player        Team     Pos  GP  W%   K   D    A  KDA    KP  ...  \
# 0    Abbedagge  Schalke 04  Middle  18  61  65  43  115  4.2  65.5  ...
# 1      Alphari      Origen     Top  18  39  47  43   65  2.6  53.6  ...
# 2       Attila    Vitality     ADC  19  42  61  46   87  3.2  67.0  ...
# 3       Broxah      Fnatic  Jungle  18  78  65  53  134  3.8  60.9  ...
# 4        Bwipo      Fnatic     Top  17  76  74  59  120  3.3  63.0  ...
# ..         ...         ...     ...  ..  ..  ..  ..  ...  ...   ...  ...
# 74  Vizicsacsi      Splyce     Top  18  67  43  51  110  3.0  59.5  ...
# 75     Woolite       Rogue     ADC  16  38  49  52   82  2.5  61.8  ...
# 76      Wunder  G2 Esports     Top  17  88  58  33  114  5.2  48.5  ...
# 77      Wunder  G2 Esports  Middle   1   0   3   6    2  0.8  45.5  ...
# 78       Xerxe      Splyce  Jungle  18  67  36  32  140  5.5  68.5  ...
#
#     CSD10  CSPM  CS%P15  DPM  DMG%   EGPM  Gold%   WPM  WCPM           Split
# 0    -1.3   8.8    26.4  509  27.7  284.9   24.2  0.46  0.20  Summer Regular
# 1    13.4   8.7    26.1  467  27.2  271.7   24.4  0.46  0.17  Summer Regular
# 2    10.1   9.7    33.1  481  26.1  306.1   26.8  0.34  0.39  Summer Regular
# 3    -6.2   4.6    13.6  297  14.8  211.2   15.9  0.63  0.29  Summer Regular
# 4    -2.1   7.7    23.1  493  23.5  292.6   22.2  0.46  0.20  Summer Regular
# ..    ...   ...     ...  ...   ...    ...    ...   ...   ...             ...
# 74    0.3   7.8    21.7  414  22.6  258.1   20.9  0.65  0.21  Summer Regular
# 75  -13.3   8.4    31.1  434  26.8  277.1   26.1  0.44  0.29  Summer Regular
# 76    4.4   7.9    22.5  456  19.4  275.1   20.1  0.41  0.13  Summer Regular
# 77   13.0   8.8    34.7  324  16.0  267.2   25.9  0.41  0.15  Summer Regular
# 78   -0.6   4.7    11.7  235  13.2  188.7   15.1  0.76  0.49  Summer Regular
#
# [79 rows x 24 columns]

# %%
print(dataset)
# Out:
# [['Abbedagge' 'Schalke 04' 'Middle' ... 0.46 0.2 'Summer Regular']
#  ['Alphari' 'Origen' 'Top' ... 0.46 0.17 'Summer Regular']
#  ['Attila' 'Vitality' 'ADC' ... 0.34 0.39 'Summer Regular']
#  ...
#  ['Wunder' 'G2 Esports' 'Top' ... 0.41 0.13 'Summer Regular']
#  ['Wunder' 'G2 Esports' 'Middle' ... 0.41 0.15 'Summer Regular']
#  ['Xerxe' 'Splyce' 'Jungle' ... 0.76 0.49 'Summer Regular']]

# %%
from sklearn import linear_model

kda = []
win_p = []

for data in dataset:
    kda.append([data[8]])
    win_p.append(data[4])

x_train = kda[0:78]
y_train = win_p[0:78]
linear = linear_model.LinearRegression()
linear.fit(x_train, y_train)
linear.score(x_train, y_train)
predicted= linear.predict(x_train)

plt.scatter(x = x_train, y = y_train)
plt.plot(x_train,predicted)
print('X: KDA, Y:Win_P')
# Out:
# X: KDA, Y:Win_P
